# %%
import pandas as pd
pd.set_option('display.max.rows', 30)

# %% [markdown]
#     Going to work on Covid 19 deaths

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\JOVANS\TestingPD\who_covid19.csv")
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 196553009
# 1    United States of America         Americas                  34564448
# 2                       India  South-East Asia                  31572344
# 3                      Brazil         Americas                  19797086
# 4          Russian Federation           Europe                   6242066
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 12 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Name                                                          238 non-null    object
#  1   WHO Region                                                    237 non-null    object
#  2   Cases - cumulative total                                      238 non-null    int64
#  3   Cases - cumulative total per 100000 population                237 non-null    float64
#  4   Cases - newly reported in last 7 days                         238 non-null    int64
#  5   Cases - newly reported in last 7 days per 100000 population   237 non-null    float64
#  6   Cases - newly reported in last 24 hours                       238 non-null    int64
# ...

# %%
df.shape
# Out:
# (238, 12)

# %%
df.head
# Out:
# <bound method NDFrame.head of                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 196553009
# 1    United States of America         Americas                  34564448
# 2                       India  South-East Asia                  31572344
# 3                      Brazil         Americas                  19797086
# 4          Russian Federation           Europe                   6242066
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
df['Name']
# Out:
# 0                        Global
# 1      United States of America
# 2                         India
# 3                        Brazil
# 4            Russian Federation
#                  ...
# 233                Saint Helena
# 234                     Tokelau
# 235                       Tonga
# 236                Turkmenistan
# 237                      Tuvalu
# Name: Name, Length: 238, dtype: object

# %%
df[df['Name'].str.contains('Brazil')]
# Out:
#      Name WHO Region  Cases - cumulative total  \
# 3  Brazil   Americas                  19797086
#
#    Cases - cumulative total per 100000 population  \
# 3                                         9313.67
#
#    Cases - newly reported in last 7 days  \
# 3                                 323132
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 3                                             152.02
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 3                                    48013                     553179
#
#    Deaths - cumulative total per 100000 population  \
# 3                                           260.25
#
#    Deaths - newly reported in last 7 days  \
# 3                                    7575
#
#    Deaths - newly reported in last 7 days per 100000 population  \
# 3                                               3.56
#
#    Deaths - newly reported in last 24 hours
# 3                                      1344

# %%
df.head
# Out:
# <bound method NDFrame.head of                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 196553009
# 1    United States of America         Americas                  34564448
# 2                       India  South-East Asia                  31572344
# 3                      Brazil         Americas                  19797086
# 4          Russian Federation           Europe                   6242066
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %% [markdown]
# How to set an Index Name

# %%
df2=df.set_index('Name')
df2
# Out:
#                                WHO Region  Cases - cumulative total  \
# Name
# Global                                NaN                 196553009
# United States of America         Americas                  34564448
# India                     South-East Asia                  31572344
# Brazil                           Americas                  19797086
# Russian Federation                 Europe                   6242066
# ...                                   ...                       ...
# Saint Helena                       Africa                         0
# Tokelau                   Western Pacific                         0
# Tonga                     Western Pacific                         0
# Turkmenistan                       Europe                         0
# Tuvalu                    Western Pacific                         0
#
#                           Cases - cumulative total per 100000 population  \
# Name
# ...

# %% [markdown]
# How to filter which contain to view

# %%
df2.filter(items = ['WHO Region','Cases - cumulative tota','Cases - newly reported in last 7 days','Cases - newly reported in last 24 hours','Deaths - cumulative tota','Deaths - newly reported in last 7 day','Deaths - newly reported in last 7 days'])
# Out:
#                                WHO Region  \
# Name
# Global                                NaN
# United States of America         Americas
# India                     South-East Asia
# Brazil                           Americas
# Russian Federation                 Europe
# ...                                   ...
# Saint Helena                       Africa
# Tokelau                   Western Pacific
# Tonga                     Western Pacific
# Turkmenistan                       Europe
# Tuvalu                    Western Pacific
#
#                           Cases - newly reported in last 7 days  \
# Name
# Global                                                  3999924
# United States of America                                 471734
# India                                                    279282
# Brazil                                                   323132
# Russian Federation                                       163544
# ...

# %%
df.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 196553009
# 1  United States of America         Americas                  34564448
# 2                     India  South-East Asia                  31572344
# 3                    Brazil         Americas                  19797086
# 4        Russian Federation           Europe                   6242066
#
#    Cases - cumulative total per 100000 population  \
# 0                                     2521.675429
# 1                                    10442.350000
# 2                                     2287.840000
# 3                                     9313.670000
# 4                                     4277.310000
#
#    Cases - newly reported in last 7 days  \
# 0                                3999924
# 1                                 471734
# 2                                 279282
# 3                                 323132
# ...

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\JOVANS\TestingPD\who_covid19.csv", index_col="WHO Region")
df.head()
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# NaN                                                 2521.675429
# Americas                                           10442.350000
# South-East Asia                                     2287.840000
# Americas                                            9313.670000
# Europe                                              4277.310000
#
#                  Cases - newly reported in last 7 days  \
# WHO Region
# NaN                                            3999924
# ...

# %%
df.loc['Tonga']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Tonga'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.loc['Tonga']
#
# ...

# %%
df.iloc[1]
# Out:
# Name                                                            United States of America
# Cases - cumulative total                                                        34564448
# Cases - cumulative total per 100000 population                                  10442.35
# Cases - newly reported in last 7 days                                             471734
# Cases - newly reported in last 7 days per 100000 population                       142.52
# Cases - newly reported in last 24 hours                                            90660
# Deaths - cumulative total                                                         607095
# Deaths - cumulative total per 100000 population                                   183.41
# Deaths - newly reported in last 7 days                                              2155
# Deaths - newly reported in last 7 days per 100000 population                        0.65
# ...

# %%
df.head()
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# NaN                                                 2521.675429
# Americas                                           10442.350000
# South-East Asia                                     2287.840000
# Americas                                            9313.670000
# Europe                                              4277.310000
#
#                  Cases - newly reported in last 7 days  \
# WHO Region
# NaN                                            3999924
# ...

# %%
dfsort=df.sort_index()
dfsort.head()
# Out:
#                   Name  Cases - cumulative total  \
# WHO Region
# Africa          Malawi                     51141
# Africa          Guinea                     25401
# Africa           Gabon                     25370
# Africa      Mauritania                     25063
# Africa        Eswatini                     24848
#
#             Cases - cumulative total per 100000 population  \
# WHO Region
# Africa                                              267.33
# Africa                                              193.42
# Africa                                             1139.85
# Africa                                              539.03
# Africa                                             2141.77
#
#             Cases - newly reported in last 7 days  \
# WHO Region
# Africa                                       4724
# Africa                                        578
# Africa                                         61
# Africa                                       1840
# ...

# %%
groupby = dfsort.groupby('Name')

# %%
groupby.mean()
# Out:
#                                                     Cases - cumulative total  \
# Name
# Afghanistan                                                         146523.0
# Albania                                                             132999.0
# Algeria                                                             168668.0
# American Samoa                                                           0.0
# Andorra                                                              14655.0
# ...                                                                      ...
# Wallis and Futuna                                                      454.0
# Yemen                                                                 7042.0
# Zambia                                                              194140.0
# Zimbabwe                                                            105656.0
# occupied Palestinian territory, including east ...                  345328.0
#
# ...

# %% [markdown]
# Numpy and Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
# ...                                   ...                       ...
# Africa                       Saint Helena                         0
# Western Pacific                   Tokelau                         0
# Western Pacific                     Tonga                         0
# Europe                       Turkmenistan                         0
# Western Pacific                    Tuvalu                         0
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# ...

# %%
df.plot.scatter(x='Cases - cumulative total per 100000 population', y = 'Deaths - cumulative total per 100000 population', s = 10, figsize=(10,5))
# Out:
# <Axes: xlabel='Cases - cumulative total per 100000 population', ylabel='Deaths - cumulative total per 100000 population'>

# %%
df.plot.area(figsize=(10,10))
# Out:
# <Axes: xlabel='WHO Region'>

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot.scatter(x='Cases - cumulative total per 100000 population', y = 'Deaths - cumulative total per 100000 population',  sizes=(20, 400), alpha=0.7)
# Out:
# <Axes: xlabel='Cases - cumulative total per 100000 population', ylabel='Deaths - cumulative total per 100000 population'>

# %%
df
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
# ...                                   ...                       ...
# Africa                       Saint Helena                         0
# Western Pacific                   Tokelau                         0
# Western Pacific                     Tonga                         0
# Europe                       Turkmenistan                         0
# Western Pacific                    Tuvalu                         0
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# ...

# %%
df.drop_duplicates()
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
# ...                                   ...                       ...
# Africa                       Saint Helena                         0
# Western Pacific                   Tokelau                         0
# Western Pacific                     Tonga                         0
# Europe                       Turkmenistan                         0
# Western Pacific                    Tuvalu                         0
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# ...

# %%
df
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
# ...                                   ...                       ...
# Africa                       Saint Helena                         0
# Western Pacific                   Tokelau                         0
# Western Pacific                     Tonga                         0
# Europe                       Turkmenistan                         0
# Western Pacific                    Tuvalu                         0
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# ...

# %% [markdown]
# correlation_coefficient

# %%
correlation_coefficient = df["Cases - cumulative total"].corr(df["Deaths - cumulative total"])
correlation_coefficient
# Out:
# 0.9955830964710338

# %%
ax = df.plot.scatter(x="Cases - cumulative total", 
                       y="Deaths - cumulative total", 
                       c='DarkBlue', 
                       loglog=True, 
                       figsize=(14, 8), 
                       title="Relationship between Cumulative Total Cases and Deaths",
                       grid=True, 
                       alpha=0.7)

ax.set_xlabel("Cumulative Total Cases")
ax.set_ylabel("Cumulative Total Deaths")

plt.show()

# %%
df3=df.groupby('WHO Region')[[
       'Cases - cumulative total per 100000 population',
       'Cases - newly reported in last 7 days per 100000 population',  
       'Deaths - cumulative total per 100000 population',
       'Deaths - newly reported in last 7 days per 100000 population'
       ]].mean().sort_values(by ='Cases - cumulative total per 100000 population')

# %%
df3
# Out:
#                        Cases - cumulative total per 100000 population  \
# WHO Region
# Western Pacific                                            929.608571
# Africa                                                    1265.062400
# South-East Asia                                           2260.477273
# Eastern Mediterranean                                     4129.813636
# Americas                                                  4439.612500
# Europe                                                    7197.292258
# Other                                                             NaN
#
#                        Cases - newly reported in last 7 days per 100000 population  \
# WHO Region
# Western Pacific                                                52.424857
# Africa                                                         34.844000
# South-East Asia                                                61.499091
# Eastern Mediterranean                                          74.126364
# ...

# %%
df3.plot()
# Out:
# <Axes: xlabel='WHO Region'>

# %%
df4=df3.transpose()

# %%
df4
# Out:
# WHO Region                                          Western Pacific  \
# Cases - cumulative total per 100000 population           929.608571
# Cases - newly reported in last 7 days per 10000...        52.424857
# Deaths - cumulative total per 100000 population            9.672571
# Deaths - newly reported in last 7 days per 1000...         0.458857
#
# WHO Region                                             Africa  \
# Cases - cumulative total per 100000 population      1265.0624
# Cases - newly reported in last 7 days per 10000...    34.8440
# Deaths - cumulative total per 100000 population       16.5126
# Deaths - newly reported in last 7 days per 1000...     0.8016
#
# WHO Region                                          South-East Asia  \
# Cases - cumulative total per 100000 population          2260.477273
# Cases - newly reported in last 7 days per 10000...        61.499091
# Deaths - cumulative total per 100000 population           17.871818
# ...

# %%
df4.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df3.columns
# Out:
# Index(['Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days per 100000 population'],
#       dtype='object')

# %%
df4.boxplot(figsize=(10,9))
# Out:
# <Axes: >

# %% [markdown]
# More Data Analysis and Visualations

# %%
df4
# Out:
# WHO Region                                          Western Pacific  \
# Cases - cumulative total per 100000 population           929.608571
# Cases - newly reported in last 7 days per 10000...        52.424857
# Deaths - cumulative total per 100000 population            9.672571
# Deaths - newly reported in last 7 days per 1000...         0.458857
#
# WHO Region                                             Africa  \
# Cases - cumulative total per 100000 population      1265.0624
# Cases - newly reported in last 7 days per 10000...    34.8440
# Deaths - cumulative total per 100000 population       16.5126
# Deaths - newly reported in last 7 days per 1000...     0.8016
#
# WHO Region                                          South-East Asia  \
# Cases - cumulative total per 100000 population          2260.477273
# Cases - newly reported in last 7 days per 10000...        61.499091
# Deaths - cumulative total per 100000 population           17.871818
# ...

# %% [markdown]
# EDA

# %%
df
# Out:
#                                      Name  Cases - cumulative total  \
# WHO Region
# NaN                                Global                 196553009
# Americas         United States of America                  34564448
# South-East Asia                     India                  31572344
# Americas                           Brazil                  19797086
# Europe                 Russian Federation                   6242066
# ...                                   ...                       ...
# Africa                       Saint Helena                         0
# Western Pacific                   Tokelau                         0
# Western Pacific                     Tonga                         0
# Europe                       Turkmenistan                         0
# Western Pacific                    Tuvalu                         0
#
#                  Cases - cumulative total per 100000 population  \
# WHO Region
# ...

# %%
df.describe()
# Out:
#        Cases - cumulative total  \
# count              2.380000e+02
# mean               1.651706e+06
# std                1.313683e+07
# min                0.000000e+00
# 25%                5.014750e+03
# 50%                5.182250e+04
# 75%                3.774782e+05
# max                1.965530e+08
#
#        Cases - cumulative total per 100000 population  \
# count                                      237.000000
# mean                                      3834.947955
# std                                       4170.716536
# min                                          0.000000
# 25%                                        277.650000
# 50%                                       2287.840000
# 75%                                       6671.150000
# max                                      18967.190000
#
#        Cases - newly reported in last 7 days  \
# count                           2.380000e+02
# mean                            3.361281e+04
# ...

# %%
df.describe(include='object')
# Out:
#           Name
# count      238
# unique     238
# top     Global
# freq         1

# %%
df.isnull().any()
# Out:
# Name                                                            False
# Cases - cumulative total                                        False
# Cases - cumulative total per 100000 population                   True
# Cases - newly reported in last 7 days                           False
# Cases - newly reported in last 7 days per 100000 population      True
# Cases - newly reported in last 24 hours                         False
# Deaths - cumulative total                                       False
# Deaths - cumulative total per 100000 population                  True
# Deaths - newly reported in last 7 days                          False
# Deaths - newly reported in last 7 days per 100000 population     True
# Deaths - newly reported in last 24 hours                        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name                                                            0
# Cases - cumulative total                                        0
# Cases - cumulative total per 100000 population                  1
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 7 days per 100000 population     1
# Cases - newly reported in last 24 hours                         0
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 100000 population                 1
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 7 days per 100000 population    1
# Deaths - newly reported in last 24 hours                        0
# dtype: int64
